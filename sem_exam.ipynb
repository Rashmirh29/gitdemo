# %% [markdown]
# <a href="https://colab.research.google.com/github/Rashmirh29/gitdemo/blob/main/sem_exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/tips.csv')
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   week    95 non-null     int64
#  1   day     95 non-null     object
#  2   n_peop  95 non-null     float64
#  3   bill    95 non-null     float64
#  4   tip     95 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 3.8+ KB
#             week     n_peop        bill        tip
# count  95.000000  95.000000   95.000000  95.000000
# mean    1.873684   2.722737   41.195263   7.338684
# std     0.802153   2.191235   31.398526   5.890313
# min     1.000000   0.670000    4.980000   0.000000
# 25%     1.000000   1.330000   21.005000   3.250000
# 50%     2.000000   2.000000   29.970000   6.000000
# 75%     3.000000   3.665000   53.215000   8.500000
# max     3.000000   9.330000  144.180000  25.952400

# %%
print("Missing values:\n", tips.isnull().sum())
# Out:
# Missing values:
#  week      0
# day       0
# n_peop    0
# bill      0
# tip       0
# dtype: int64

# %%
print("replce the Missing values:\n", tips.isnull().sum())
# Out:
# replce the Missing values:
#  week      0
# day       0
# n_peop    0
# bill      0
# tip       0
# dtype: int64

# %%
plt.scatter(tips["bill"], tips["tip"])
plt.title("Total Bill and Tips")
plt.show()
