# %% [markdown]
# <a href="https://colab.research.google.com/github/Rashmirh29/gitdemo/blob/main/exam3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
x=df[['weight']]
x
# Out:
#      weight
# 0      3504
# 1      3693
# 2      3436
# 3      3433
# 4      3449
# ..      ...
# 393    2790
# 394    2130
# 395    2295
# 396    2625
# 397    2720
#
# [398 rows x 1 columns]

# %%
y=df[['mpg']]
y
# Out:
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [398 rows x 1 columns]

# %%
sns.scatterplot(data=df,x=df['weight'],y=df['mpg'])
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      weight
# 73     4098
# 288    3830
# 270    2515
# 250    3735
# 28     4732
# ..      ...
# 191    3233
# 71     2330
# 63     4385
# 331    2145
# 170    2592
#
# [318 rows x 1 columns]

# %%
x_test
# Out:
#      weight
# 314    2870
# 267    2560
# 290    4054
# 218    1825
# 308    2556
# ..      ...
# 6      4354
# 228    3525
# 146    2125
# 367    2605
# 77     2511
#
# [80 rows x 1 columns]

# %%
y_train
# Out:
#       mpg
# 73   13.0
# 288  18.2
# 270  21.1
# 250  19.4
# 28    9.0
# ..    ...
# 191  22.0
# 71   19.0
# 63   14.0
# 331  33.8
# 170  23.0
#
# [318 rows x 1 columns]

# %%
y_test
# Out:
#       mpg
# 314  26.4
# 267  27.5
# 290  15.5
# 218  36.0
# 308  33.5
# ..    ...
# 6    14.0
# 228  18.5
# 146  28.0
# 367  28.0
# 77   22.0
#
# [80 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)
print("x_pred",x_pred)
print("y_pred",y_pred)
# Out:
# x_pred [[14.68888393]
#  [16.80140703]
#  [27.16695877]
#  [17.55024917]
#  [ 9.69134796]
#  [17.62907466]
#  [26.02398919]
#  [30.24115283]
#  [21.21563439]
#  [14.2474612 ]
#  [28.19169012]
#  [17.62907466]
#  [27.50590837]
#  [25.27514705]
#  [29.49231069]
#  [18.10991014]
#  [21.26292968]
#  [18.51192013]
#  [30.24115283]
#  [13.76662572]
#  [20.11207755]
#  [20.50620499]
#  [29.49231069]
#  [25.35397254]
#  [18.04684975]
#  [15.02783353]
#  [19.16617168]
#  [22.79214416]
#  [28.23898542]
#  [10.19583108]
#  [22.67390592]
#  [24.02182178]
#  [32.527092  ]
#  [17.15612172]
#  [15.93432665]
#  [29.72878715]
#  [30.20174008]
#  [24.13217746]
#  [20.0726648 ]
#  [22.09847986]
#  [28.86170678]
#  [26.11857977]
#  [23.77746276]
#  [25.39338528]
#  [13.30155533]
#  [30.35939106]
#  [14.35781688]
#  [26.18164017]
#  [30.20174008]
#  [28.86170678]
#  [21.15257399]
#  [24.95984509]
#  [23.22568434]
#  [16.48610507]
#  [22.66602338]
#  [23.03650317]
#  [16.88023251]
#  [17.21918212]
# ...

# %%
y_test
# Out:
#       mpg
# 314  26.4
# 267  27.5
# 290  15.5
# 218  36.0
# 308  33.5
# ..    ...
# 6    14.0
# 228  18.5
# 146  28.0
# 367  28.0
# 77   22.0
#
# [80 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# np.float64(4.784286334308679)

# %%
print("mse",mse)
print("mae",mae)
print("r2",r2)
# Out:
# mse 22.88939572865278
# mae 3.676339851234675
# r2 0.6619919543226287

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,x_pred,color='red')
plt.title('weight vs mpg')
plt.xlabel('weight')
plt.ylabel('mpg')
plt.show()
